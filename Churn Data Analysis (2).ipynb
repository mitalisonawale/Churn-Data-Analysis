# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\mital\Downloads\customer_churn_data.csv")
df.head()
# Out:
#    year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0  2015       100198  409-8743  Female   36                     62
# 1  2015       100643  340-5930  Female   39                    149
# 2  2015       100756  372-3750  Female   65                    126
# 3  2015       101595  331-4902  Female   24                    131
# 4  2015       101653  351-8398  Female   40                    191
#
#   multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 0           no              no               148.35                12.2
# 1           no              no               294.45                 7.7
# 2           no              no                87.30                11.9
# 3           no             yes               321.30                 9.5
# 4           no              no               243.00                10.9
#
#    maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 0               16.81                     82               1
# ...

# %%
df.shape
# Out:
# (2000, 16)

# %%
df.size
# Out:
# 32000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    2000 non-null   int64
#  1   customer_id             2000 non-null   int64
#  2   phone_no                2000 non-null   object
#  3   gender                  1976 non-null   object
#  4   age                     2000 non-null   int64
#  5   no_of_days_subscribed   2000 non-null   int64
#  6   multi_screen            2000 non-null   object
#  7   mail_subscribed         2000 non-null   object
#  8   weekly_mins_watched     2000 non-null   float64
#  9   minimum_daily_mins      2000 non-null   float64
#  10  maximum_daily_mins      2000 non-null   float64
#  11  weekly_max_night_mins   2000 non-null   int64
#  12  videos_watched          2000 non-null   int64
#  13  maximum_days_inactive   1972 non-null   float64
# ...

# %%
df.describe(include="all")
# Out:
#           year    customer_id  phone_no gender         age  \
# count   2000.0    2000.000000      2000   1976  2000.00000
# unique     NaN            NaN      2000      2         NaN
# top        NaN            NaN  409-8743   Male         NaN
# freq       NaN            NaN         1   1053         NaN
# mean    2015.0  554887.157500       NaN    NaN    38.69050
# std        0.0  261033.690318       NaN    NaN    10.20641
# min     2015.0  100198.000000       NaN    NaN    18.00000
# 25%     2015.0  328634.750000       NaN    NaN    32.00000
# 50%     2015.0  567957.500000       NaN    NaN    37.00000
# 75%     2015.0  773280.250000       NaN    NaN    44.00000
# max     2015.0  999961.000000       NaN    NaN    82.00000
#
#         no_of_days_subscribed multi_screen mail_subscribed  \
# count             2000.000000         2000            2000
# unique                    NaN            2               2
# top                       NaN           no              no
# ...

# %%
df.isnull().sum()
# Out:
# year                       0
# customer_id                0
# phone_no                   0
# gender                    24
# age                        0
# no_of_days_subscribed      0
# multi_screen               0
# mail_subscribed            0
# weekly_mins_watched        0
# minimum_daily_mins         0
# maximum_daily_mins         0
# weekly_max_night_mins      0
# videos_watched             0
# maximum_days_inactive     28
# customer_support_calls     0
# churn                     35
# dtype: int64

# %%
#missing percentage
df["gender"].isnull().sum()/len(df)
# Out:
# 0.012

# %%
#missing percentrage more than 30 should be dropped

# %%
df["gender"].dtypes
# Out:
# dtype('O')

# %%
for col in df.columns:
    if df[col].dtypes in [int,float]:
        df[col].fillna(df[col].median(),inplace = True)
    else:
        df[col].fillna(df[col].mode()[0],inplace = True)

# %%
df.isnull().sum()
# Out:
# year                      0
# customer_id               0
# phone_no                  0
# gender                    0
# age                       0
# no_of_days_subscribed     0
# multi_screen              0
# mail_subscribed           0
# weekly_mins_watched       0
# minimum_daily_mins        0
# maximum_daily_mins        0
# weekly_max_night_mins     0
# videos_watched            0
# maximum_days_inactive     0
# customer_support_calls    0
# churn                     0
# dtype: int64

# %%
df["phone_no"].dtypes
# Out:
# dtype('O')

# %%
df["phone_no"]=df["phone_no"].astype(str).str.replace("-"," ")

# %%
df
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0     2015       100198  409 8743  Female   36                     62
# 1     2015       100643  340 5930  Female   39                    149
# 2     2015       100756  372 3750  Female   65                    126
# 3     2015       101595  331 4902  Female   24                    131
# 4     2015       101653  351 8398  Female   40                    191
# ...    ...          ...       ...     ...  ...                    ...
# 1995  2015       997132  385 7387  Female   54                     75
# 1996  2015       998086  383 9255    Male   45                    127
# 1997  2015       998474  353 2080    Male   53                     94
# 1998  2015       998934  359 7788    Male   40                     94
# 1999  2015       999961  414 1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
df["churn"].mean()
# Out:
# 0.131

# %%
df["gender"].value_counts()
# Out:
# gender
# Male      1077
# Female     923
# Name: count, dtype: int64

# %%
df["multi_screen"].value_counts()
# Out:
# multi_screen
# no     1802
# yes     198
# Name: count, dtype: int64

# %%
#Most of the users has subscribed t0 single screen service.

# %%
df.groupby("gender")["no_of_days_subscribed"].mean()
# Out:
# gender
# Female    99.826652
# Male      99.684308
# Name: no_of_days_subscribed, dtype: float64

# %%
df.groupby("gender")["videos_watched"].mean()
# Out:
# gender
# Female    4.408451
# Male      4.545961
# Name: videos_watched, dtype: float64

# %%
#Male users has watched more videos than female users

# %%
df.groupby("gender")["multi_screen"].value_counts()
# Out:
# gender  multi_screen
# Female  no              835
#         yes              88
# Male    no              967
#         yes             110
# Name: count, dtype: int64

# %%
df.groupby("gender")["weekly_max_night_mins"].mean()
# Out:
# gender
# Female     99.707476
# Male      101.022284
# Name: weekly_max_night_mins, dtype: float64

# %%
#Male are the more binge behiaviour users .Male users watch the content at night.

# %%
df.columns
# Out:
# Index(['year', 'customer_id', 'phone_no', 'gender', 'age',
#        'no_of_days_subscribed', 'multi_screen', 'mail_subscribed',
#        'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#        'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
#        'customer_support_calls', 'churn'],
#       dtype='object')

# %%
df.groupby("gender")["maximum_days_inactive"].mean()
# Out:
# gender
# Female    3.223185
# Male      3.267409
# Name: maximum_days_inactive, dtype: float64

# %%
df.groupby("gender")["customer_support_calls"].mean()
# Out:
# gender
# Female    1.536295
# Male      1.556175
# Name: customer_support_calls, dtype: float64

# %%
df.groupby("gender")["churn"].mean()
# Out:
# gender
# Female    0.136511
# Male      0.126277
# Name: churn, dtype: float64

# %%
#Overall churn rate of female is more than male , i.e higher number of females has stopped using the service.

# %%
df["age"].value_counts()
# Out:
# age
# 36    104
# 38    102
# 35     97
# 37     94
# 34     86
#      ...
# 77      1
# 82      1
# 80      1
# 76      1
# 79      1
# Name: count, Length: 63, dtype: int64

# %%
# Most of the users are of Age 36

# %%
df["mail_subscribed"].value_counts()
# Out:
# mail_subscribed
# no     1430
# yes     570
# Name: count, dtype: int64

# %%
#Most of the users has no subscribed to mail this indicates the engagement level .

# %%
df[["churn","weekly_mins_watched"]].corr()
# Out:
#                         churn  weekly_mins_watched
# churn                1.000000             0.162876
# weekly_mins_watched  0.162876             1.000000

# %%
df[["churn","minimum_daily_mins"]].corr()
# Out:
#                        churn  minimum_daily_mins
# churn               1.000000            0.066646
# minimum_daily_mins  0.066646            1.000000

# %%
df[["churn","maximum_daily_mins"]].corr()
# Out:
#                        churn  maximum_daily_mins
# churn               1.000000            0.162874
# maximum_daily_mins  0.162874            1.000000

# %%
#df[["no_of_days_subscribed","weekly_max_night_mins"]].corr()

# %%
#df[["no_of_days_subscribed","videos_watched"]].corr()

# %%
#df[["no_of_days_subscribed","churn"]].corr()

# %%
df[["videos_watched","weekly_mins_watched"]].corr()
# Out:
#                      videos_watched  weekly_mins_watched
# videos_watched             1.000000             0.018619
# weekly_mins_watched        0.018619             1.000000

# %%
#df[["videos_watched","minimum_daily_mins"]].corr()

# %%
df[["videos_watched","maximum_daily_mins"]].corr()
# Out:
#                     videos_watched  maximum_daily_mins
# videos_watched            1.000000            0.018621
# maximum_daily_mins        0.018621            1.000000

# %%
#df[["videos_watched","weekly_max_night_mins"]].corr()

# %%
#df[["weekly_mins_watched","maximum_daily_mins"]].corr()

# %%
df.groupby("gender")["maximum_daily_mins"].max()
# Out:
# gender
# Female    56.83
# Male      59.64
# Name: maximum_daily_mins, dtype: float64

# %%
#Male user has spent maximum amount of time to watch content on any day in week.

# %%
df.groupby("gender")["weekly_mins_watched"].max()
# Out:
# gender
# Female    501.45
# Male      526.20
# Name: weekly_mins_watched, dtype: float64

# %%
#Male user has spent maximum amount of time to watch content on in week.

# %%
df["weekly_mins_watched"].max()
# Out:
# 526.2

# %%
df["videos_watched"].value_counts()
# Out:
# videos_watched
# 3     408
# 4     354
# 2     295
# 5     285
# 6     201
# 7     132
# 1     101
# 8      70
# 9      61
# 10     32
# 11     19
# 0      10
# 12     10
# 13      8
# 15      6
# 14      4
# 18      2
# 19      1
# 16      1
# Name: count, dtype: int64

# %%
#Most of the users has watched the content for three days

# %%
df[["customer_support_calls","churn"]].corr()
# Out:
#                         customer_support_calls     churn
# customer_support_calls                1.000000  0.204774
# churn                                 0.204774  1.000000

# %%
df[df["customer_support_calls"] == 3]
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 3     2015       101595  331 4902  Female   24                    131
# 11    2015       103738  392 5296    Male   34                    107
# 17    2015       107195  386 9981  Female   45                     99
# 25    2015       108961  373 5732    Male   50                    137
# 29    2015       111118  418 8450    Male   37                     48
# ...    ...          ...       ...     ...  ...                    ...
# 1979  2015       988979  392 2722    Male   38                     81
# 1982  2015       989415  394 8006    Male   25                     95
# 1987  2015       991641  403 4298    Male   35                    157
# 1992  2015       994954  329 3222  Female   42                    119
# 1998  2015       998934  359 7788    Male   40                     94
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# ...

# %%
#If the users makes more than 3 customer support calls ,then service can have high risk of churn.

# %%
df.groupby("multi_screen")["churn"].mean()
# Out:
# multi_screen
# no     0.102109
# yes    0.393939
# Name: churn, dtype: float64

# %%
#If the user has multi screen plan then the service has high risk of churn

# %%
df[df["churn"]==True].head(3)
# Out:
#    year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 2  2015       100756  372 3750  Female   65                    126
# 5  2015       101953  329 6603    Male   31                     65
# 7  2015       103225  348 7193  Female   40                     50
#
#   multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 2           no              no                87.30                11.9
# 5           no              no               193.65                12.7
# 7           no              no               196.65                 5.6
#
#    maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 2                9.89                     91               1
# 5               21.95                    111               6
# 7               22.29                     88               9
#
#    maximum_days_inactive  customer_support_calls  churn
# 2                    4.0                       5    1.0
# ...

# %%
df[df["churn"]==False].head(6)
# Out:
#    year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0  2015       100198  409 8743  Female   36                     62
# 1  2015       100643  340 5930  Female   39                    149
# 3  2015       101595  331 4902  Female   24                    131
# 4  2015       101653  351 8398  Female   40                    191
# 6  2015       103051  416 1845    Male   54                     59
# 8  2015       103408  413 4039    Male   61                    205
#
#   multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 0           no              no               148.35                12.2
# 1           no              no               294.45                 7.7
# 3           no             yes               321.30                 9.5
# 4           no              no               243.00                10.9
# 6           no              no               239.25                10.2
# ...

# %%
#If least amount of time spent by the user is smaller than the maximum amount of time spent,then the service has least risk of churn

# %%
#1.	Is there a significant difference in churn rate across genders?
df.groupby("gender")["churn"].mean()
# Out:
# gender
# Female    0.136511
# Male      0.126277
# Name: churn, dtype: float64

# %%
#The churn rate female users is more than male users

# %%
#2.	Do customers with multi-screen access churn less often than those without it?
df.groupby("multi_screen")["churn"].mean()
# Out:
# multi_screen
# no     0.102109
# yes    0.393939
# Name: churn, dtype: float64

# %%
#3.	What is the average age of churned vs. retained customers?
df.groupby("churn")["age"].mean()
# Out:
# churn
# 0.0    38.643843
# 1.0    39.000000
# Name: age, dtype: float64

# %%
#4.	Does a longer subscription period correlate with a lower churn rate?
df.groupby("churn")["no_of_days_subscribed"].mean()
# Out:
# churn
# 0.0     99.711162
# 1.0    100.007634
# Name: no_of_days_subscribed, dtype: float64

# %%
#Here the churned users actually stayed slightly longer on average.
#So, longer subscription period does not strongly correlate with lower churn in your data.

# %%
#4.	How does weekly watch time affect churn? Are heavy watchers less likely to churn?
df.groupby("churn")["weekly_mins_watched"].mean()
# Out:
# churn
# 0.0    265.085731
# 1.0    303.961260
# Name: weekly_mins_watched, dtype: float64

# %%
#The uses who watch the content for more time in a week has high chance of getting churn.
#Because some users may leave once they consume what they want.
#Users may watch heavily during a free trial and then churn.
#Some users may watch alot then cancel.

# %%
#5.	Is there a consistent daily watch pattern among non-churned users?
non_churned=df[df["churn"]==False]

# %%
non_churned["daily variation"] = non_churned["maximum_daily_mins"]-non_churned["minimum_daily_mins"]

# %%
non_churned.head()
# Out:
#    year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0  2015       100198  409 8743  Female   36                     62
# 1  2015       100643  340 5930  Female   39                    149
# 3  2015       101595  331 4902  Female   24                    131
# 4  2015       101653  351 8398  Female   40                    191
# 6  2015       103051  416 1845    Male   54                     59
#
#   multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 0           no              no               148.35                12.2
# 1           no              no               294.45                 7.7
# 3           no             yes               321.30                 9.5
# 4           no              no               243.00                10.9
# 6           no              no               239.25                10.2
#
#    maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 0               16.81                     82               1
# ...

# %%
avg_variation = non_churned["daily variation"].mean()
avg_variation
# Out:
# 19.916973532796316

# %%
#6.	Whether users do watch content at night tend to churn more or less?
df.groupby("churn")["weekly_max_night_mins"].mean()
# Out:
# churn
# 0.0    100.363061
# 1.0    100.763359
# Name: weekly_max_night_mins, dtype: float64

# %%
#7.	How many videos does an average churned vs. non-churned customer watch per week?
df.groupby("churn")["videos_watched"].mean()
# Out:
# churn
# 0.0    4.501151
# 1.0    4.358779
# Name: videos_watched, dtype: float64

# %%
#8.	Does email subscription affect churn behavior (mail_subscribed vs. churn)?
df.groupby("mail_subscribed")["churn"].mean()
# Out:
# mail_subscribed
# no     0.147552
# yes    0.089474
# Name: churn, dtype: float64

# %%
#The users do not have  email notification are more likely to churn.

# %%
#9.	What is the average number of inactive days in a week for churned users?
churned =df[df["churn"]==True]
churned["maximum_days_inactive"].mean()
# Out:
# 3.3396946564885495

# %%
#The users who are more likely to churn are on average inactive for 3 days in a week.

# %%
#10.Do users who contact customer support frequently also show lower engagement (fewer minutes/videos watched)?
df.groupby("customer_support_calls")["videos_watched"].mean()
# Out:
# customer_support_calls
# 0    4.523810
# 1    4.461119
# 2    4.486111
# 3    4.433071
# 4    4.533981
# 5    4.736842
# 6    3.363636
# 7    5.333333
# 8    6.000000
# 9    3.000000
# Name: videos_watched, dtype: float64

# %%
#From the output we can see that ,the users who have call for customer support more frequently have also watched more videos .
#So we cannot say that frequent customer calls shows lower engagement.

# %%
#11.What is the distribution of churn among high vs. low engagement users?
df.groupby("videos_watched")["churn"].mean()
# Out:
# videos_watched
# 0     0.000000
# 1     0.178218
# 2     0.179661
# 3     0.117647
# 4     0.115819
# 5     0.108772
# 6     0.119403
# 7     0.136364
# 8     0.114286
# 9     0.147541
# 10    0.156250
# 11    0.157895
# 12    0.100000
# 13    0.000000
# 14    0.000000
# 15    0.500000
# 16    0.000000
# 18    0.000000
# 19    0.000000
# Name: churn, dtype: float64

# %%
#The users with lower engagement are more likely to churn and users with higher engagement are less likely to churn.

# %%
#12.Can consistency in viewing (low difference between max and min daily minutes) reduce churn?
df["Diff_max_min_daily_min"]=df["maximum_daily_mins"]- df["minimum_daily_mins"]

# %%
df.groupby("churn")["Diff_max_min_daily_min"].mean()
# Out:
# churn
# 0.0    19.916974
# 1.0    23.772748
# Name: Diff_max_min_daily_min, dtype: float64

# %%
#If the user watch the content consistently then the risk of user to get churn is reduced.

# %%
#df

# %%
#df.drop("Difference",axis=1)

# %%
#13.Are users with high peak daily watch time more loyal or more likely to churn suddenly?
df.groupby("churn")["maximum_daily_mins"].mean()
# Out:
# churn
# 0.0    30.043613
# 1.0    34.449466
# Name: maximum_daily_mins, dtype: float64

# %%
#The users with maximum daily watch time are more likely to churn.
#So we can say that the users who watch content for maximum time are binge users who watch and then leave ,they are not loyal users whi stay longer.

# %%
#18.What is the churn rate among users with short subscriptions and long subscriptions?
df.groupby("churn")["no_of_days_subscribed"].mean()
# Out:
# churn
# 0.0     99.711162
# 1.0    100.007634
# Name: no_of_days_subscribed, dtype: float64

# %%
#From the output we can say that users with long subscription are more likely to churn i.e they are not the loyal users.
#These are the users who subscibed for more days but they do not watch more content.

# %%
#17.Can we cluster customers into different personas based on their usage and churn behaviour? (Groupby)
a = df.groupby("churn").agg({"videos_watched":"mean","weekly_mins_watched":"mean","maximum_daily_mins":"mean" , "customer_id":"count"})
a
# Out:
#        videos_watched  weekly_mins_watched  maximum_daily_mins  customer_id
# churn
# 0.0          4.501151           265.085731           30.043613         1738
# 1.0          4.358779           303.961260           34.449466          262

# %%
import matplotlib.pyplot as plt

# %%
gender = df.groupby("gender")["churn"].mean()
age = df["age"].head()
